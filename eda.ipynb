# %% [markdown]
# <center><h2> Behavioral Risk Factor Data: Tobacco Use (2011 to present)</h2></center>
# <center><h3> Subtitle  </h3></center><br></br>
# <center><h4>Authors:</h4></center>
#
# <center><h4>Yashar Mansouri & Nasrin Khansari</h4></center>

# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# !pip install sodapy # run this line if sodapy is not installed

from sodapy import Socrata

# %% [markdown]
# ## Data Description & Resources
#
# **Data Last Updated**: December 11, 2018
#
# **Metadata Last Updated**: February 14, 2019
#
# **Date Created**: June 3, 2014
#
# **Data Provided by**: Centers for Disease Control and Prevention, National Center for Chronic Disease Prevention and Health Promotion, Office on Smoking and Health
#
# **Publisher**: Centers for Disease Control and Prevention
#
# **Contact Name**: OSHData Support
#
# **Contact Email**: OSHData@cdc.gov
#
# **Bureau Code**: 009:20
#
# **Program Code**: 009:020
#
# **Public Access Level**: Public Domain
#
# **Data Dictionary**: https://chronicdata.cdc.gov/Survey-Data/Behavioral-Risk-Factor-Data-Tobacco-Use-2011-to-pr/wsas-xwh5
#
# **References**: https://chronicdata.cdc.gov/d/5amh-5sx3
#
# **Glossary/Methodology**: https://chronicdata.cdc.gov/d/5amh-5sx3
#
# **Category**: Survey Data
#
# **Tags**: osh, office on smoking and health, state system, tobacco, survey, behavioral, risk, surveillance, tobacco use, cigarette, cigarette use, adult, smoking, smoking status, smoker, current, former, never, ever, frequency, every day, some days, demographics, age, gender, race, ethnicity, education, cessation, quit, prevalence, brfss
#
# **License**: Public Domain
#
# **Source Link**: http://www.cdc.gov/brfss/

# %% [markdown]
# ## A quick brief on the data:
#
# ### Source
# Behavioral Risk Factor Surveillance System Survey Data
#
# ### Methods
# The BRFSS is a continuous, state-based surveillance system that collects information about modifiable risk factors for chronic diseases and other leading causes of death. The data for the STATE System were extracted from the annual BRFSS surveys from participating states. For estimates among racial and ethnic subgroups, two-year combined data are available. Sample sizes of less than 50 were considered to be inadequate for data analysis. The STATE System does not display percentages for these sample sizes; instead, "NA" will appear in the percentage box for that demographic group.
#
# ### Sampling
#
# For 2011 data and forward, a random-digit dialing system was used to select samples of adults in households with landline or cellular telephones. The sample represented adults from each state who were civilian, aged 18 years or older and not institutionalized. Most states now use a computer-assisted telephone interviewing software program (CATI). This allows the interviewer to enter the data directly into a computer, thus reducing errors and eliminating unacceptable responses. More detailed information on the sampling methodology is located on the BRFSS website (http://www.cdc.gov/brfss/)."
#
# ### Questionnaire
#
# The questionnaire was composed of three sets of questions:
#
# 1. A core set of questions asked in all participating states.
# 2. A standard module containing questions on selected topics developed by CDC and asked at the discretion of each state.
# 3. Questions developed for a particular state to meet a particular need.
#
# The core questions allow data to be compared between states. Because many of the same questions are asked each year, emerging health trends can be identified and monitored.
#
# **Notes**: "NA" indicates that survey data are not available.
#
# **Citation**: Centers for Disease Control and Prevention (CDC). Behavioral Risk Factor Surveillance System Survey Data. Atlanta, Georgia: U.S. Department of Health and Human Services, Centers for Disease Control and Prevention, 2019.

# %%
#importing data

client = Socrata("chronicdata.cdc.gov", None)

#total rows of data is 33451, setting limit to 35000 to capture all data

results = client.get("wsas-xwh5", limit=35000)

# Convert to pandas DataFrame

df = pd.DataFrame.from_records(results)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %% [markdown]
# Notes about the cols_to_drop:
#
# 1. **'topictype'** is Tobacco Use - Survey Data on all entries
# 2. **'topictypeid** is BEH on all entries
# 2. **'topicid', 'measureid', 'stratificationid1', 'stratificationid2', 'stratificationid3','stratificationid4', 'submeasureid', 'displayorder'** are not needed since theyre used on CDC's application.
# 3. **':@computed_region_bxsw_vy29', ':@computed_region_he4y_prf8'** created while importing via API and unnecessary
# 4. **'data_value_footnote', 'data_value_footnote_symbol'** unnecessary since null data_values are dropped based on these twp column
# 5. **'datasource'** is BRFSS on all entries
# 6. **'data_value_type'** is Percentage on all entries
# 7. **'data_value_unit'** is % on all entries

# %%
#dropping the unnecessary columns by reordering the required ones for better analysis purposes:
df = df[['year', 'locationabbr', 'locationdesc', 'topicdesc', 'measuredesc','age', 'race', 'education', 'response', 'sample_size', 'data_value', 'data_value_std_err', 'low_confidence_limit', 'high_confidence_limit']]

# %%
#dropping null values based on the data_value
df.dropna(subset = ['data_value', 'sample_size'], inplace = True)

# %%
#checking for duplicates
df.duplicated().sum() > 0
# Out:
# False

# %%
df.isna().sum()
#we'll keep the null response values
# Out:
# year                         0
# locationabbr                 0
# locationdesc                 0
# topicdesc                    0
# measuredesc                  0
# age                          0
# race                         0
# education                    0
# response                 20852
# sample_size                  0
# data_value                   0
# data_value_std_err           0
# low_confidence_limit         0
# high_confidence_limit        0
# dtype: int64

# %%
df.education.unique()
# Out:
# array(['All Grades', '< 12th Grade', '> 12th Grade', '12th Grade'],
#       dtype=object)

# %%
df.year.unique()
# Out:
# array(['2017', '2016-2017', '2016', '2015-2016', '2015', '2014-2015',
#        '2014', '2013-2014', '2013', '2012-2013', '2012', '2011-2012',
#        '2011'], dtype=object)

# %%
df.query(' year == "2011-2012"')

# %%
#dropping 2 consecutive years/ cumulative data
idx_drop = df.query('(year == "2011-2012") | (year == "2013-2014") | (year == "2014-2015") | (year == "2015-2016") | (year == "2016-2017")').index

df.drop(idx_drop, inplace = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29098 entries, 0 to 33450
# Data columns (total 14 columns):
# year                     29098 non-null object
# locationabbr             29098 non-null object
# locationdesc             29098 non-null object
# topicdesc                29098 non-null object
# measuredesc              29098 non-null object
# age                      29098 non-null object
# race                     29098 non-null object
# education                29098 non-null object
# response                 10995 non-null object
# sample_size              29098 non-null object
# data_value               29098 non-null object
# data_value_std_err       29098 non-null object
# low_confidence_limit     29098 non-null object
# high_confidence_limit    29098 non-null object
# dtypes: object(14)
# memory usage: 3.3+ MB

# %%
df
# Out:
#        year locationabbr locationdesc                       topicdesc  \
# 0      2017           AL      Alabama  Smokeless Tobacco Use (Adults)
# 1      2017           AL      Alabama              Cessation (Adults)
# 2      2017           AL      Alabama  Smokeless Tobacco Use (Adults)
# 3      2017           AL      Alabama          Cigarette Use (Adults)
# 4      2017           AL      Alabama          Cigarette Use (Adults)
# 6      2017           AL      Alabama          Cigarette Use (Adults)
# 7      2017           AL      Alabama  Smokeless Tobacco Use (Adults)
# 8      2017           AL      Alabama  Smokeless Tobacco Use (Adults)
# 9      2017           AL      Alabama  Smokeless Tobacco Use (Adults)
# 10     2017           AL      Alabama          Cigarette Use (Adults)
# 11     2017           AL      Alabama              Cessation (Adults)
# 12     2017           AL      Alabama          Cigarette Use (Adults)
# 13     2017           AL      Alabama          Cigarette Use (Adults)
# 14     2017           AL      Alabama          Cigarette Use (Adults)
# 15     2017           AL      Alabama        E-Cigarette Use (Adults)
# 16     2017           AL      Alabama          Cigarette Use (Adults)
# 17     2017           AL      Alabama          Cigarette Use (Adults)
# 18     2017           AL      Alabama        E-Cigarette Use (Adults)
# 19     2017           AL      Alabama        E-Cigarette Use (Adults)
# 20     2017           AL      Alabama          Cigarette Use (Adults)
# 21     2017           AL      Alabama          Cigarette Use (Adults)
# 22     2017           AL      Alabama          Cigarette Use (Adults)
# 23     2017           AL      Alabama          Cigarette Use (Adults)
# 24     2017           AL      Alabama        E-Cigarette Use (Adults)
# 25     2017           AL      Alabama          Cigarette Use (Adults)
# 26     2017           AL      Alabama        E-Cigarette Use (Adults)
# 27     2017           AL      Alabama        E-Cigarette Use (Adults)
# 28     2017           AL      Alabama  Smokeless Tobacco Use (Adults)
# 29     2017           AL      Alabama        E-Cigarette Use (Adults)
# 30     2017           AL      Alabama  Smokeless Tobacco Use (Adults)
# ...     ...          ...          ...                             ...
# 33420  2011           WY      Wyoming          Cigarette Use (Adults)
# 33421  2011           WY      Wyoming          Cigarette Use (Adults)
# 33422  2011           WY      Wyoming          Cigarette Use (Adults)
# 33423  2011           WY      Wyoming          Cigarette Use (Adults)
# 33424  2011           WY      Wyoming  Smokeless Tobacco Use (Adults)
# 33425  2011           WY      Wyoming  Smokeless Tobacco Use (Adults)
# 33426  2011           WY      Wyoming              Cessation (Adults)
# 33427  2011           WY      Wyoming          Cigarette Use (Adults)
# 33428  2011           WY      Wyoming          Cigarette Use (Adults)
# 33430  2011           WY      Wyoming  Smokeless Tobacco Use (Adults)
# 33431  2011           WY      Wyoming  Smokeless Tobacco Use (Adults)
# 33432  2011           WY      Wyoming  Smokeless Tobacco Use (Adults)
# 33433  2011           WY      Wyoming  Smokeless Tobacco Use (Adults)
# 33434  2011           WY      Wyoming  Smokeless Tobacco Use (Adults)
# 33435  2011           WY      Wyoming          Cigarette Use (Adults)
# 33436  2011           WY      Wyoming  Smokeless Tobacco Use (Adults)
# 33437  2011           WY      Wyoming          Cigarette Use (Adults)
# 33438  2011           WY      Wyoming          Cigarette Use (Adults)
# 33439  2011           WY      Wyoming              Cessation (Adults)
# 33440  2011           WY      Wyoming          Cigarette Use (Adults)
# 33441  2011           WY      Wyoming          Cigarette Use (Adults)
# 33442  2011           WY      Wyoming  Smokeless Tobacco Use (Adults)
# 33443  2011           WY      Wyoming  Smokeless Tobacco Use (Adults)
# 33444  2011           WY      Wyoming          Cigarette Use (Adults)
# 33445  2011           WY      Wyoming  Smokeless Tobacco Use (Adults)
# 33446  2011           WY      Wyoming  Smokeless Tobacco Use (Adults)
# 33447  2011           WY      Wyoming              Cessation (Adults)
# 33448  2011           WY      Wyoming          Cigarette Use (Adults)
# 33449  2011           WY      Wyoming          Cigarette Use (Adults)
# 33450  2011           WY      Wyoming  Smokeless Tobacco Use (Adults)
#
#                                              measuredesc                 age  \
# 0                                            Current Use      45 to 64 Years
# 1           Percent of Former Smokers Among Ever Smokers            All Ages
# 2                                       Frequency of Use            All Ages
# 3                                        Current Smoking            All Ages
# 4                                        Current Smoking      18 to 44 Years
# 6                                      Smoking Frequency            All Ages
# 7                                            User Status            All Ages
# 8                                            Current Use            All Ages
# 9                                       Frequency of Use            All Ages
# 10                                        Smoking Status            All Ages
# 11          Percent of Former Smokers Among Ever Smokers            All Ages
# 12                                       Current Smoking    Age 25 and Older
# 13                                       Current Smoking            All Ages
# 14                                       Current Smoking    Age 25 and Older
# 15                                           Current Use    Age 25 and Older
# 16                                        Smoking Status            All Ages
# 17                                       Current Smoking    Age 20 and Older
# 18                                           Current Use      18 to 44 Years
# 19                                           User Status            All Ages
# 20                                        Smoking Status            All Ages
# 21                                     Smoking Frequency            All Ages
# 22                                       Current Smoking            All Ages
# 23                                        Smoking Status            All Ages
# 24                                           Current Use            All Ages
# 25                                       Current Smoking            All Ages
# 26                                      Frequency of Use            All Ages
# 27                                           User Status            All Ages
# 28                                           Current Use    Age 25 and Older
# 29                                           Current Use            All Ages
# 30                                           Current Use    Age 20 and Older
# ...                                                  ...                 ...
# 33420                                  Smoking Frequency            All Ages
# 33421                                  Smoking Frequency            All Ages
# 33422                                    Current Smoking            All Ages
# 33423                                    Current Smoking            All Ages
# 33424                                        User Status            All Ages
# 33425                                        Current Use            All Ages
# 33426       Percent of Former Smokers Among Ever Smokers            All Ages
# 33427                                    Current Smoking            All Ages
# 33428                                     Smoking Status            All Ages
# 33430                                        Current Use    Age 25 and Older
# 33431                                   Frequency of Use            All Ages
# 33432                                        Current Use            All Ages
# 33433                                        Current Use            All Ages
# 33434                                   Frequency of Use            All Ages
# 33435                                     Smoking Status            All Ages
# 33436                                   Frequency of Use            All Ages
# 33437                                  Smoking Frequency            All Ages
# 33438                                    Current Smoking    Age 25 and Older
# 33439  Quit Attempt in Past Year Among Every Day Ciga...            All Ages
# 33440                                     Smoking Status            All Ages
# 33441                                    Current Smoking  65 Years and Older
# 33442                                   Frequency of Use            All Ages
# 33443                                        Current Use      18 to 24 Years
# 33444                                    Current Smoking      18 to 44 Years
# 33445                                        User Status            All Ages
# 33446                                        Current Use    Age 20 and Older
# 33447  Quit Attempt in Past Year Among Every Day Ciga...            All Ages
# 33448                                  Smoking Frequency            All Ages
# 33449                                     Smoking Status            All Ages
# 33450                                        Current Use    Age 20 and Older
#
#                                 race     education     response sample_size  \
# 0                          All Races    All Grades          NaN        2413
# 1                          All Races    All Grades          NaN        2834
# 2                          All Races    All Grades    Some Days         272
# 3      American Indian/Alaska Native    All Grades          NaN          78
# 4                          All Races    All Grades          NaN         962
# 6                          All Races    All Grades    Some Days         532
# 7                          All Races    All Grades  Not Current        6491
# 8                          All Races    All Grades          NaN        2600
# 9                          All Races    All Grades    Some Days          59
# 10                         All Races    All Grades      Current        2598
# 11                         All Races    All Grades          NaN        1424
# 12                         All Races  < 12th Grade          NaN         749
# 13                             White    All Grades          NaN        4401
# 14                         All Races  > 12th Grade          NaN        3576
# 15                         All Races  > 12th Grade          NaN        3560
# 16                         All Races    All Grades      Current        3871
# 17                         All Races    12th Grade          NaN        1877
# 18                         All Races    All Grades          NaN         956
# 19                         All Races    All Grades      Current        3855
# 20                         All Races    All Grades      Current        6472
# 21                         All Races    All Grades    Every Day        1143
# 22                         All Races    All Grades          NaN        2598
# 23                         All Races    All Grades       Former        2598
# 24                         All Races    All Grades          NaN        6441
# 25                         All Races    All Grades          NaN        6472
# 26                         All Races    All Grades    Some Days         226
# 27                         All Races    All Grades       Former        3855
# 28                         All Races  < 12th Grade          NaN         754
# 29                  African American    All Grades          NaN        1591
# 30                         All Races  > 12th Grade          NaN        3741
# ...                              ...           ...          ...         ...
# 33420                      All Races    All Grades    Some Days        1249
# 33421                      All Races    All Grades    Some Days         555
# 33422                       Hispanic    All Grades          NaN         287
# 33423                      All Races    All Grades          NaN        6840
# 33424                      All Races    All Grades      Current        4018
# 33425                      All Races    All Grades          NaN        4018
# 33426                      All Races    All Grades          NaN        1766
# 33427                          White    All Grades          NaN        6201
# 33428                      All Races    All Grades       Former        4010
# 33430                      All Races  > 12th Grade          NaN        4120
# 33431                      All Races    All Grades    Some Days         471
# 33432         Asian/Pacific Islander    All Grades          NaN          97
# 33433                      All Races    All Grades          NaN        6861
# 33434                      All Races    All Grades    Some Days          50
# 33435                      All Races    All Grades        Never        4010
# 33436                      All Races    All Grades    Some Days         421
# 33437                      All Races    All Grades    Every Day        1249
# 33438                      All Races  > 12th Grade          NaN        4112
# 33439                      All Races    All Grades          NaN         417
# 33440                      All Races    All Grades       Former        2830
# 33441                      All Races    All Grades          NaN        2040
# 33442                      All Races    All Grades    Every Day          50
# 33443                      All Races    All Grades          NaN         320
# 33444                      All Races    All Grades          NaN        1069
# 33445                      All Races    All Grades  Not Current        2843
# 33446                      All Races  < 12th Grade          NaN         396
# 33447                      All Races    All Grades          NaN         944
# 33448                      All Races    All Grades    Every Day         555
# 33449                      All Races    All Grades      Current        2830
# 33450                      All Races  > 12th Grade          NaN        4243
#
#       data_value data_value_std_err low_confidence_limit  \
# 0            6.5                0.6                  5.2
# 1           52.8                1.3                 50.3
# 2           37.7                3.8                 30.3
# 3           40.2                7.8                   25
# 4           21.9                1.7                 18.5
# 6           32.4                2.7                 27.1
# 7           93.7                0.4                 92.8
# 8           11.5                0.8                  9.8
# 9             69                7.6                 54.1
# 10          23.4                1.2                 21.1
# 11          55.5                1.8                   52
# 12          35.7                2.3                 31.1
# 13          20.5                0.9                 18.8
# 14          14.4                0.8                 12.9
# 15           3.8                0.5                  2.9
# 16          18.7                0.9                 16.9
# 17          26.9                1.5                   24
# 18             5                0.9                  3.2
# 19           3.9                0.5                    3
# 20          20.9                0.7                 19.5
# 21          65.4                1.9                 61.7
# 22          23.4                1.2                 21.1
# 23          29.3                1.1                 27.1
# 24           4.9                0.4                  4.1
# 25          20.9                0.7                 19.5
# 26          67.1                4.2                   59
# 27          14.2                0.9                 12.5
# 28           8.7                1.3                  6.2
# 29           2.2                0.5                  1.3
# 30           4.5                0.5                  3.5
# ...          ...                ...                  ...
# 33420       23.9                1.7                 20.6
# 33421       25.8                2.5                 20.9
# 33422       26.8                3.5                 19.9
# 33423         23                0.8                 21.5
# 33424        1.5                0.3                  0.9
# 33425        1.5                0.3                  0.9
# 33426       50.9                1.8                 47.3
# 33427       22.1                0.8                 20.5
# 33428       22.6                  1                 20.7
# 33430        8.4                0.7                  7.1
# 33431       35.1                2.8                 29.6
# 33432       17.8                5.4                  7.2
# 33433        9.8                0.5                  8.8
# 33434       52.5                9.8                 33.2
# 33435       55.6                1.2                 53.2
# 33436       33.7                2.9                   28
# 33437       76.1                1.7                 72.8
# 33438       16.7                0.9                 14.9
# 33439       51.4                3.2                 45.1
# 33440       29.6                1.2                 27.3
# 33441       11.8                1.1                  9.6
# 33442       47.5                9.8                 28.2
# 33443       12.8                1.9                  9.1
# 33444         24                1.7                 20.6
# 33445       82.1                  1                 80.2
# 33446         10                  2                  6.1
# 33447       48.4                2.3                 43.9
# 33448       74.2                2.5                 69.3
# 33449       24.2                1.2                 21.9
# 33450        8.6                0.7                  7.3
#
#       high_confidence_limit     count
# 0                       7.8   24136.5
# 1                      55.3  283452.8
# 2                      45.1   27237.7
# 3                      55.4    7840.2
# 4                      25.3   96221.9
# 6                      37.7   53232.4
# 7                      94.6  649193.7
# 8                      13.2  260011.5
# 9                      83.9      5969
# 10                     25.7  259823.4
# 11                       59  142455.5
# 12                     40.3   74935.7
# 13                     22.2  440120.5
# 14                     15.9  357614.4
# 15                      4.7   35603.8
# 16                     20.5  387118.7
# 17                     29.8  187726.9
# 18                      6.8      9565
# 19                      4.8   38553.9
# 20                     22.3  647220.9
# 21                     69.1  114365.4
# 22                     25.7  259823.4
# 23                     31.5  259829.3
# 24                      5.7   64414.9
# 25                     22.3  647220.9
# 26                     75.2   22667.1
# 27                     15.9  385514.2
# 28                     11.2    7548.7
# 29                      3.1   15912.2
# 30                      5.5   37414.5
# ...                     ...       ...
# 33420                  27.2  124923.9
# 33421                  30.7   55525.8
# 33422                  33.7   28726.8
# 33423                  24.5    684023
# 33424                   2.1   40181.5
# 33425                   2.1   40181.5
# 33426                  54.5  176650.9
# 33427                  23.7  620122.1
# 33428                  24.5  401022.6
# 33430                   9.7   41208.4
# 33431                  40.6   47135.1
# 33432                  28.4    9717.8
# 33433                  10.8   68619.8
# 33434                  71.8    5052.5
# 33435                    58  401055.6
# 33436                  39.4   42133.7
# 33437                  79.4  124976.1
# 33438                  18.5  411216.7
# 33439                  57.7   41751.4
# 33440                  31.9  283029.6
# 33441                    14  204011.8
# 33442                  66.8    5047.5
# 33443                  16.5   32012.8
# 33444                  27.4    106924
# 33445                    84  284382.1
# 33446                  13.9     39610
# 33447                  52.9   94448.4
# 33448                  79.1   55574.2
# 33449                  26.5  283024.2
# 33450                   9.9   42438.6
#
# [31847 rows x 15 columns]
